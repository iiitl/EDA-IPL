# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/matches.csv")
print(f"Shape: {df.shape}")
print(f"Column names: {df.columns.tolist()}")
print(f"Number of unique seasons:{df['season'].nunique()}")
print("Number of missing data: ")
print(df.isnull().sum())

season_counts = df["season"].value_counts().sort_index()
season_counts.plot(kind='bar', color= 'blue', edgecolor='black', figsize=(10,5))
plt.title("Number of matches played per season")
plt.xlabel("season")
plt.ylabel("Match Count")
plt.plot()
# Out:
# Shape: (1095, 20)
# Column names: ['id', 'season', 'city', 'date', 'match_type', 'player_of_match', 'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result', 'result_margin', 'target_runs', 'target_overs', 'super_over', 'method', 'umpire1', 'umpire2']
# Number of unique seasons:17
# Number of missing data:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64
# []
